# %% [markdown]
# # **Week-2 Live Session-1**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the Dataset and Important Info of Data

# %%
titanic = pd.read_csv('/content/train.csv')

# %%
# type of the dataset

type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
titanic.corr()
# Out:
# <ipython-input-11-c1c691e9860d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# ...

# %%
# Plotting histogram

titanic.hist()

# %% [markdown]
# #### SETTING FEATURES MATRIX AND LABEL VECTOR

# %%
features = titanic.drop(['Survived'], axis = 1)
label = titanic['Survived']

# %%
features.shape, label.shape
# Out:
# ((891, 11), (891,))

# %% [markdown]
# #### TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(features, label, test_size = 0.2, random_state = 28)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((712, 11), (179, 11), (712,), (179,))

# %%
X_train.index
# Out:
# Int64Index([309, 469, 593,  62, 500, 733, 218, 455, 662, 262,
#             ...
#             492, 407, 192, 140,  87, 259,  32, 278, 517, 257],
#            dtype='int64', length=712)

# %%
titanic['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# #### TRAIN TEST SPLIT USING CROSS VALIDATION

# %% [markdown]
# 1. K-Fold

# %%
from sklearn.model_selection import KFold

# %%
kfs = KFold(n_splits = 5, shuffle = True, random_state = 28)

# %% [markdown]
# #### DATA CLEANING AND DATA PREPROCESSING

# %%
titanic.select_dtypes('number').columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
titanic.select_dtypes(exclude = 'number').columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
num_cols = ['Age']
cat_cols = ['Sex','Embarked']

# %% [markdown]
# ###### SIMPLE IMPUTER

# %%
from sklearn.impute import SimpleImputer

# %%
SI_num = SimpleImputer(strategy = 'mean') # AGE
SI_cat = SimpleImputer(strategy = 'most_frequent') #CABIN, EMBARKED

# %% [markdown]
# ###### ONE HOT ENCODER AND STANDARD SCALER

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
ohe = OneHotEncoder(sparse_output = False)

# %% [markdown]
# ###### COLUMN TRANSFORMER AND PIPELINE

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
pipe_num = Pipeline([
    ('numeric', SI_num),
    ('scaler', StandardScaler())
])

pipe_cat = Pipeline([
    ('categorical', SI_cat),
    ('encode', ohe)
])

preprocessor = ColumnTransformer([
    ('Num', pipe_num, num_cols),
    ('Cat', pipe_cat, cat_cols)
], remainder = 'drop')

# %%
X_transformed = preprocessor.fit_transform(X_train)

# %%
X_transformed.shape
# Out:
# (712, 6)

# %%
preprocessor.get_feature_names_out()
# Out:
# array(['Num__Age', 'Cat__Sex_female', 'Cat__Sex_male', 'Cat__Embarked_C',
#        'Cat__Embarked_Q', 'Cat__Embarked_S'], dtype=object)

# %% [markdown]
# # **Week-2 Live Session-2**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
adult = pd.read_csv('/content/adult.csv')

# %% [markdown]
# ##### DATA INFORMATION

# %%
adult.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
adult.describe(include = 'all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   48842.000000     48842  4.884200e+04     48842     48842.000000
# unique           NaN         9           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33906           NaN     15784              NaN
# mean       38.643585       NaN  1.896641e+05       NaN        10.078089
# std        13.710510       NaN  1.056040e+05       NaN         2.570973
# min        17.000000       NaN  1.228500e+04       NaN         1.000000
# 25%        28.000000       NaN  1.175505e+05       NaN         9.000000
# 50%        37.000000       NaN  1.781445e+05       NaN        10.000000
# 75%        48.000000       NaN  2.376420e+05       NaN        12.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status      occupation relationship   race gender  \
# ...

# %%
adult.shape
# Out:
# (48842, 15)

# %% [markdown]
# ##### DROP SOME FEATURES

# %%
adult.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
adult.drop(['capital-gain', 'capital-loss'], axis = 1, inplace = True)
adult.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  hours-per-week  \
# 0  Machine-op-inspct    Own-child  Black    Male              40
# 1    Farming-fishing      Husband  White    Male              50
# 2    Protective-serv      Husband  White    Male              40
# 3  Machine-op-inspct      Husband  Black    Male              40
# 4                  ?    Own-child  White  Female              30
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States   >50K
# ...

# %%
adult.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'hours-per-week', 'native-country', 'income'],
#       dtype='object')

# %%
adult.shape
# Out:
# (48842, 13)

# %% [markdown]
# ##### NULL VALUES AND DUPLICATE INSTANCES

# %%
adult.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
adult.isin(['?']).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
adult.replace(['?'], np.nan, inplace = True)

# %%
adult.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %% [markdown]
# How to find which rows has null values?

# %%
adult[adult.isna().any(axis = 1)]
# Out:
#        age workclass  fnlwgt     education  educational-num  \
# 4       18       NaN  103497  Some-college               10
# 6       29       NaN  227026       HS-grad                9
# 13      58       NaN  299831       HS-grad                9
# 19      40   Private   85019     Doctorate               16
# 22      72       NaN  132015       7th-8th                4
# ...    ...       ...     ...           ...              ...
# 48811   35       NaN  320084     Bachelors               13
# 48812   30       NaN   33811     Bachelors               13
# 48820   71       NaN  287372     Doctorate               16
# 48822   41       NaN  202822       HS-grad                9
# 48823   72       NaN  129912       HS-grad                9
#
#            marital-status      occupation   relationship                race  \
# 4           Never-married             NaN      Own-child               White
# 6           Never-married             NaN      Unmarried               Black
# ...

# %% [markdown]
# ##### UNIQUES VALUES FOR ALL FEATURES

# %%
adult.nunique(axis = 0)
# Out:
# age                   74
# workclass              8
# fnlwgt             28523
# education             16
# educational-num       16
# marital-status         7
# occupation            14
# relationship           6
# race                   5
# gender                 2
# hours-per-week        96
# native-country        41
# income                 2
# dtype: int64

# %%
adult['education'].value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
adult.drop(['educational-num'], inplace = True, axis = 1)

# %%
adult.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
adult.shape
# Out:
# (48842, 12)

# %% [markdown]
# ##### CORRELATION AND HEATMAP

# %%
adult.select_dtypes('number').columns
# Out:
# Index(['age', 'fnlwgt', 'hours-per-week'], dtype='object')

# %%
adult.corr()
# Out:
# <ipython-input-30-1ebceb99c6d9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   adult.corr()
#                      age    fnlwgt  hours-per-week
# age             1.000000 -0.076628        0.071558
# fnlwgt         -0.076628  1.000000       -0.013519
# hours-per-week  0.071558 -0.013519        1.000000

# %%
sns.heatmap(adult.corr(), annot = True)
# Out:
# <ipython-input-34-02a1caab9c53>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(adult.corr(), annot = True)
# <Axes: >

# %% [markdown]
# Find the gender distribution and age distribution. Find for how many given datapoints, age is in between 18 to 50?

# %%
sns.boxplot(x = adult['gender'], y = adult['age'])
print("Number of people aged between 18 to 50:" , adult['age'].between(18,50).sum())
# Out:
# Number of people aged between 18 to 50: 38439

# %%
sns.histplot(adult['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ##### FEATURES AND LABELS

# %%
features = adult.drop(['income'], axis = 1)
label = adult['income']

features.shape, label.shape
# Out:
# ((48842, 11), (48842,))

# %%
label.value_counts()
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %% [markdown]
# ##### ENCODING THE LABELS

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelenc = LabelEncoder()

label = labelenc.fit_transform(label) #alphabetically encodes as 0 and 1

# %%
np.count_nonzero(label)/ len(label)
# Out:
# 0.23928176569346055

# %% [markdown]
# ##### TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(features, label, random_state = 28, stratify = label, test_size = 0.2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((39073, 11), (9769, 11), (39073,), (9769,))

# %% [markdown]
# ##### PREPROCESSING

# %% [markdown]
# * Imputing null values
# * Scaling
# * Encoding categorical values

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA

# %%
num_cols = X_train.select_dtypes('number').columns

# %%
cat_cols = X_train.select_dtypes(exclude = 'number').columns

# %%
num_pipe = Pipeline([
    ('impute_num', SimpleImputer(strategy = 'mean')),
    ('scale', MinMaxScaler())
])

cat_pipe = Pipeline([
    ('impute_cat', SimpleImputer(strategy = 'most_frequent')),
    ('encode', OrdinalEncoder())
])

preprocessor = ColumnTransformer([
    ('Numerical', num_pipe, num_cols),
    ('Categorical', cat_pipe, cat_cols)
], remainder = 'passthrough')

# %%
X_trans = preprocessor.fit_transform(X_train)

# %%
X_trans.shape
# Out:
# (39073, 11)

# %% [markdown]
# ##### BALANCE THE DATASET

# %% [markdown]
# * Under Sampling
# * Over Sampling
# * SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE()

X_balanced, y_balanced = smote.fit_resample(X_trans, y_train)

# %%
np.count_nonzero(y_balanced)/ len(y_balanced)
# Out:
# 0.5

# %% [markdown]
# ##### PCA

# %%
# To reduce dimensions

pipePCA = Pipeline([
    ('preprocess', preprocessor),
    ('pca', PCA(n_components = 2))
])

PCA_X = pipePCA.fit_transform(X_train)

PCA_X.shape
# Out:
# (39073, 2)

# %% [markdown]
# ##### OTHER METHODS

# %% [markdown]
# Dict Vectorizer

# %%
data = [{'age': 4, 'height':96.0},
        {'age': 1, 'height':73.9},
        {'age': 3, 'height':88.9},
        {'age': 2, 'height':81.6}]

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dv = DictVectorizer(sparse= False)
trans_data = dv.fit_transform(data)

# %%
trans_data
# Out:
# array([[ 4. , 96. ],
#        [ 1. , 73.9],
#        [ 3. , 88.9],
#        [ 2. , 81.6]])

# %% [markdown]
# Variance Threshold

# %%
np.var(trans_data, axis = 0)
# Out:
# array([ 1.25 , 67.735])

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
vt = VarianceThreshold(threshold = 9)
vt.fit_transform(trans_data)
# Out:
# array([[96. ],
#        [73.9],
#        [88.9],
#        [81.6]])
